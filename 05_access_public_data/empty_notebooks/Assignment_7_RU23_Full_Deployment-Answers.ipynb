# %% [markdown]
# # Assignment 7: RU23 Full Deployment Data Visualization
# #### Now that 23 is in, let's look at the data from the glider, using what code we know and adding a few more features

# %%
# Our usual imports
import xarray as xr
import pandas as pd
import matplotlib.pyplot as plt
import cool_maps.plot as cplt
import cartopy.crs as ccrs
import cmocean.cm as cmo

# %matplotlib notebook

# %%
# Load in the URL for the Real-Time Science data from tabledap http://slocum-data.marine.rutgers.edu/erddap/tabledap/ru23-20221011T1759-profile-sci-rt.html
url  = 'http://slocum-data.marine.rutgers.edu/erddap/tabledap/ru23-20221011T1759-profile-sci-rt.csv?time%2Clatitude%2Clongitude%2Cdepth%2Ctrajectory%2Csource_file%2Cbeta_470nm%2Cbeta_532nm%2Cbeta_660nm%2Cconductivity%2Cconductivity_hysteresis_test%2Cconductivity_qartod_climatology_test%2Cconductivity_qartod_flat_line_test%2Cconductivity_qartod_gross_range_test%2Cconductivity_qartod_rate_of_change_test%2Cconductivity_qartod_spike_test%2Cconductivity_qartod_summary_flag%2Ccrs%2Cctd41cp_timestamp%2Cdensity%2Cdensity_qartod_climatology_test%2Cdensity_qartod_flat_line_test%2Cdensity_qartod_rate_of_change_test%2Cdensity_qartod_spike_test%2Cdensity_qartod_summary_flag%2Cinstrument_bb3slo%2Cinstrument_ctd%2Cinstrument_fl3slo%2Cm_pitch%2Cm_roll%2Cplatform%2Cpotential_temperature%2Cpressure%2Cpressure_qartod_flat_line_test%2Cpressure_qartod_gross_range_test%2Cpressure_qartod_pressure_test%2Cpressure_qartod_rate_of_change_test%2Cpressure_qartod_spike_test%2Cpressure_qartod_summary_flag%2Cprofile_id%2Cprofile_lat%2Cprofile_lon%2Cprofile_time%2Csalinity%2Csalinity_qartod_climatology_test%2Csalinity_qartod_flat_line_test%2Csalinity_qartod_rate_of_change_test%2Csalinity_qartod_spike_test%2Csalinity_qartod_summary_flag%2Csci_fl3slo_cdom_units%2Csci_fl3slo_chlor_units%2Csci_fl3slo_phyco_units%2Csci_m_present_time%2Csci_water_pressure%2Csound_speed%2Ctemperature%2Ctemperature_hysteresis_test%2Ctemperature_qartod_climatology_test%2Ctemperature_qartod_flat_line_test%2Ctemperature_qartod_gross_range_test%2Ctemperature_qartod_rate_of_change_test%2Ctemperature_qartod_spike_test%2Ctemperature_qartod_summary_flag%2Cu%2Cv%2Cwater_depth&time%3E=2022-10-11T19%3A27%3A56.64Z&time%3C=2022-11-01T14%3A49%3A57.49Z'
ru23_rt = pd.read_csv(url, sep=',', skiprows=range(1, 2), parse_dates=['time'])
ru23_rt
# Out:
#                                    time   latitude  longitude     depth  \
# 0      2022-10-11 19:27:56.640000+00:00  39.309335 -74.315296  4.019188
# 1      2022-10-11 19:28:00.680000+00:00  39.309334 -74.315285  4.654311
# 2      2022-10-11 19:28:04.710000+00:00  39.309332 -74.315274  5.418442
# 3      2022-10-11 19:28:08.770000+00:00  39.309331 -74.315262  6.202416
# 4      2022-10-11 19:28:09.420000+00:00  39.309330 -74.315260       NaN
# ...                                 ...        ...        ...       ...
# 129010 2022-11-01 14:49:41.320000+00:00  39.461180 -74.195801  3.989361
# 129011 2022-11-01 14:49:43.990000+00:00  39.461177 -74.195810       NaN
# 129012 2022-11-01 14:49:48.980000+00:00  39.461171 -74.195827       NaN
# 129013 2022-11-01 14:49:49.370000+00:00  39.461171 -74.195829  2.669506
# 129014 2022-11-01 14:49:53.930000+00:00  39.461166 -74.195845       NaN
#
#                 trajectory                       source_file  beta_470nm  \
# ...

# %%
# Look at just our data columns that we can work with
ru23_rt.keys()
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'trajectory', 'source_file',
#        'beta_470nm', 'beta_532nm', 'beta_660nm', 'conductivity',
#        'conductivity_hysteresis_test', 'conductivity_qartod_climatology_test',
#        'conductivity_qartod_flat_line_test',
#        'conductivity_qartod_gross_range_test',
#        'conductivity_qartod_rate_of_change_test',
#        'conductivity_qartod_spike_test', 'conductivity_qartod_summary_flag',
#        'crs', 'ctd41cp_timestamp', 'density',
#        'density_qartod_climatology_test', 'density_qartod_flat_line_test',
#        'density_qartod_rate_of_change_test', 'density_qartod_spike_test',
#        'density_qartod_summary_flag', 'instrument_bb3slo', 'instrument_ctd',
#        'instrument_fl3slo', 'm_pitch', 'm_roll', 'platform',
#        'potential_temperature', 'pressure', 'pressure_qartod_flat_line_test',
#        'pressure_qartod_gross_range_test', 'pressure_qartod_pressure_test',
# ...

# %%
# Now we can plot our data on top of a nice map from Mike Smith's cool_maps
extent     = [-75, -73, 38, 40]
markersize = 5;

fig,ax  = cplt.create(extent, proj=ccrs.Mercator(), bathymetry=True, isobaths=(-1000, -500, -100, -50, -20, -10), figsize=(10,6), oceancolor='w')
ax_posi = plt.scatter(ru23_rt['longitude'],ru23_rt['latitude'],ru23_rt['depth'],c=ru23_rt['time'], marker="o", edgecolors='none',cmap='cool', transform=ccrs.PlateCarree())

#Add in a title
plt.title('MOO Endurance Line Deployment of RU23');

# Date colorbar code taken from: https://stackoverflow.com/questions/51160705/plot-time-series-with-colorbar-in-pandas-matplotlib
# Define your mappable for colorbar creation
sm = plt.cm.ScalarMappable(cmap='cool', 
                           norm=plt.Normalize(vmin=ru23_rt['time'].min().value,
                                              vmax=ru23_rt['time'].max().value));
sm._A = [];
# Add your colorbar
cbar = plt.colorbar(sm);
# Change the numeric ticks into ones that match. Time format options detailed here: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
cbar.ax.set_yticklabels(pd.to_datetime(cbar.get_ticks()).strftime(date_format='%b %d'));
# Out:
# <div id='302ddc62-ef10-4647-87bc-09341ba04148'></div>

# %% [markdown]
# #### The above plot looks pretty good. Let's look at that code one more time though...
# ax_posi = plt.scatter(ru23_rt['longitude'],ru23_rt['latitude'],ru23['depth'],c=ru23_rt['time'], marker="o", edgecolors='none',cmap='plasma', transform=ccrs.PlateCarree())
# #### We're plotting in 3 dimensions (longitude, latitude, and depth) but we only see a 2D plot? Can't we just leave out depth?
# ###
# ### Of course we *could*, but do we want to?
# #### What if instead we visualize our data using all three of the dimensions plotted?
# #### Let's take that same block of code from above, and rework it a bit...

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(projection='3d')

# Converts the time into a usable color range for 3D plotting
ru23_rt['date'] = pd.to_numeric(pd.to_datetime(ru23_rt['time']))

ax.scatter(ru23_rt['longitude'],ru23_rt['latitude'],-ru23_rt['depth'],c=ru23_rt['date'], marker="o", edgecolors='none',cmap='cool')

#Add in a title
plt.title('MOO Endurance Line Deployment of RU23');

# Date colorbar code taken from: https://stackoverflow.com/questions/51160705/plot-time-series-with-colorbar-in-pandas-matplotlib
# Define your mappable for colorbar creation
sm = plt.cm.ScalarMappable(cmap='cool', 
                           norm=plt.Normalize(vmin=ru23_rt['time'].min().value,
                                              vmax=ru23_rt['time'].max().value));
sm._A = [];
# Add your colorbar
cbar = plt.colorbar(sm);
# Change the numeric ticks into ones that match. Time format options detailed here: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
cbar.ax.set_yticklabels(pd.to_datetime(cbar.get_ticks()).strftime(date_format='%b %d'));

ax.view_init(30, 300)
# Out:
# <div id='c279f05a-fa08-46d4-a3d1-8af95a7b1336'></div>

# %% [markdown]
# #### Now what if we wanted to look at some ocean conditions instead?

# %%
# We can plot these in 2D
fig = plt.figure(figsize=(10,6))
plt.scatter(ru23_rt['time'],-ru23_rt['depth'],10,ru23_rt['temperature'],vmin=12, vmax=22, marker="o", edgecolors='none',cmap = cmo.thermal)
cb = plt.colorbar()
cb.set_label('Temperature [°C]')
# Out:
# <div id='cd4bca5e-a1e4-4024-92d1-ef34b235e59c'></div>

# %%
# Or in 3D
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(projection='3d')

ru23_rt['date'] = pd.to_numeric(pd.to_datetime(ru23_rt['time']))

ax_temp = ax.scatter(ru23_rt['longitude'],ru23_rt['latitude'],-ru23_rt['depth'],c=ru23_rt['temperature'],vmin=12, vmax=22, marker="o", edgecolors='none',cmap=cmo.thermal)

#Add in a title
plt.title('MOO Endurance Line Deployment of RU23');

# Add your colorbar
cb = plt.colorbar(ax_temp)
cb.set_label('Temperature [°C]')

ax.view_init(30, 300)
# Out:
# <div id='cd84a84c-64cd-4879-97a0-e8f65a0f879e'></div>

# %% [markdown]
# # Assignment: Can you create some 2D or 3D plots of the glider's full deployment (delayed dataset, ru23_de)?

# %%
# Load in the URL for the Delayed Science data from tabledap http://slocum-data.marine.rutgers.edu/erddap/tabledap/ru23-20221011T1759-profile-sci-delayed.html
url  = 'http://slocum-data.marine.rutgers.edu/erddap/tabledap/ru23-20221011T1759-profile-sci-delayed.csv?time%2Clatitude%2Clongitude%2Cdepth%2Ctrajectory%2Csource_file%2Cbb3slo_timestamp%2Cbeta_470nm%2Cbeta_470nm_reference%2Cbeta_470nm_signal%2Cbeta_532nm%2Cbeta_532nm_reference%2Cbeta_532nm_signal%2Cbeta_660nm%2Cbeta_660nm_reference%2Cconductivity%2Cconductivity_hysteresis_test%2Cconductivity_qartod_climatology_test%2Cconductivity_qartod_flat_line_test%2Cconductivity_qartod_gross_range_test%2Cconductivity_qartod_rate_of_change_test%2Cconductivity_qartod_spike_test%2Cconductivity_qartod_summary_flag%2Ccrs%2Cctd41cp_timestamp%2Cdensity%2Cdensity_qartod_climatology_test%2Cdensity_qartod_flat_line_test%2Cdensity_qartod_rate_of_change_test%2Cdensity_qartod_spike_test%2Cdensity_qartod_summary_flag%2Cfl3slo_timestamp%2Cglider_altitude%2Cinstrument_bb3slo%2Cinstrument_ctd%2Cinstrument_fl3slo%2Cm_pitch%2Cm_roll%2Cm_science_clothesline_lag%2Cplatform%2Cpotential_temperature%2Cpressure%2Cpressure_qartod_flat_line_test%2Cpressure_qartod_gross_range_test%2Cpressure_qartod_pressure_test%2Cpressure_qartod_rate_of_change_test%2Cpressure_qartod_spike_test%2Cpressure_qartod_summary_flag%2Cprofile_id%2Cprofile_lat%2Cprofile_lon%2Cprofile_time%2Csalinity%2Csalinity_qartod_climatology_test%2Csalinity_qartod_flat_line_test%2Csalinity_qartod_rate_of_change_test%2Csalinity_qartod_spike_test%2Csalinity_qartod_summary_flag%2Csci_bb3slo_is_installed%2Csci_bb3slo_temp%2Csci_ctd41cp_is_installed%2Csci_ctd41cp_sim_is_installed%2Csci_fl3slo_cdom_ref%2Csci_fl3slo_cdom_sig%2Csci_fl3slo_cdom_units%2Csci_fl3slo_chlor_ref%2Csci_fl3slo_chlor_sig%2Csci_fl3slo_chlor_units%2Csci_fl3slo_is_installed%2Csci_fl3slo_phyco_ref%2Csci_fl3slo_phyco_sig%2Csci_fl3slo_phyco_units%2Csci_fl3slo_temp%2Csci_m_present_time%2Csci_software_ver%2Csci_water_pressure%2Csound_speed%2Ctemperature%2Ctemperature_hysteresis_test%2Ctemperature_qartod_climatology_test%2Ctemperature_qartod_flat_line_test%2Ctemperature_qartod_gross_range_test%2Ctemperature_qartod_rate_of_change_test%2Ctemperature_qartod_spike_test%2Ctemperature_qartod_summary_flag%2Cu%2Cv%2Cwater_depth&time%3E=2022-10-11T18%3A01%3A46.79Z&time%3C=2022-11-01T14%3A50%3A04.54Z'
ru23_de = pd.read_csv(url, sep=',', skiprows=range(1, 2), parse_dates=['time'])
ru23_de
# Out:
#                                    time   latitude  longitude     depth  \
# 0      2022-10-11 18:01:46.790000+00:00  39.313988 -74.316260  0.178632
# 1      2022-10-11 18:01:47.800000+00:00  39.313987 -74.316261       NaN
# 2      2022-10-11 18:01:49.450000+00:00  39.313985 -74.316262       NaN
# 3      2022-10-11 18:01:49.820000+00:00  39.313985 -74.316262       NaN
# 4      2022-10-11 18:01:50.820000+00:00  39.313984 -74.316262  0.178632
# ...                                 ...        ...        ...       ...
# 941012 2022-11-01 14:50:00.520000+00:00  39.461159 -74.195868  0.813757
# 941013 2022-11-01 14:50:01.520000+00:00  39.461158 -74.195871  0.654975
# 941014 2022-11-01 14:50:02.530000+00:00  39.461157 -74.195875       NaN
# 941015 2022-11-01 14:50:03.540000+00:00  39.461155 -74.195878  0.337412
# 941016 2022-11-01 14:50:04.170000+00:00  39.461155 -74.195880       NaN
#
#                 trajectory                       source_file bb3slo_timestamp  \
# ...

# %% [markdown]
# ### #1. A figure with 4-subplots of 2D (time, depth) plots showing temperature, salinity, density, and chlorophyll

# %%
# Create the figure
fig = plt.figure(figsize=(10.0, 10.0));

# And add panels to plot in then start adding variables
axes1 = fig.add_subplot(2, 2, 1);
ax1 = axes1.scatter(ru23_rt['time'],-ru23_rt['depth'],10,ru23_rt['temperature'],vmin=12, vmax=22, marker="o", edgecolors='none',cmap = cmo.thermal);
cb = plt.colorbar(ax1);
cb.set_label('Temperature [°C]');
plt.xticks(rotation = 30); # Rotates X-Axis Ticks by 45-degrees

axes2 = fig.add_subplot(2, 2, 2);
ax2 = axes2.scatter(ru23_rt['time'],-ru23_rt['depth'],10,ru23_rt['salinity'], marker="o", edgecolors='none',cmap = cmo.haline);
cb = plt.colorbar(ax2);
cb.set_label('Salinity [psu]');
plt.xticks(rotation = 30); # Rotates X-Axis Ticks by 45-degrees

axes3 = fig.add_subplot(2, 2, 3);
ax3 = axes3.scatter(ru23_rt['time'],-ru23_rt['depth'],10,ru23_rt['density'], marker="o", edgecolors='none',cmap = cmo.dense);
cb = plt.colorbar(ax3);
cb.set_label('Density [kg m-3]');
plt.xticks(rotation = 30); # Rotates X-Axis Ticks by 45-degrees

axes4 = fig.add_subplot(2, 2, 4);
ax4 = axes4.scatter(ru23_rt['time'],-ru23_rt['depth'],10,ru23_rt['sci_fl3slo_chlor_units'], vmin=0, vmax=4, marker="o", edgecolors='none',cmap = cmo.algae);
cb = plt.colorbar(ax4);
cb.set_label('Chlorophyll-a [ug L-1]');
plt.xticks(rotation = 30); # Rotates X-Axis Ticks by 45-degrees
# Out:
# <div id='83836355-ac78-4377-acf7-f8ff73e4c402'></div>

# %% [markdown]
# ### #2. A figure with 4-subplots of daily mean time series plots showing temperature, salinity, density, and chlorophyll

# %%
daily = ru23_rt.groupby(pd.Grouper(key='time', freq='D')).mean()
daily = daily.reset_index(level=0)
daily
# Out:
#                         time   latitude  longitude      depth  beta_470nm  \
# 0  2022-10-11 00:00:00+00:00  39.305913 -74.298760  10.167276    0.001427
# 1  2022-10-12 00:00:00+00:00  39.254613 -74.135564  13.855896    0.000783
# 2  2022-10-13 00:00:00+00:00  39.165437 -73.852976  19.268877    0.000452
# 3  2022-10-14 00:00:00+00:00  39.055168 -73.594612  24.731012    0.000439
# 4  2022-10-15 00:00:00+00:00  38.940145 -73.397797  31.925170    0.000508
# 5  2022-10-16 00:00:00+00:00  38.849699 -73.245600  38.633488    0.000455
# 6  2022-10-17 00:00:00+00:00  38.803183 -73.107385  46.395401    0.000378
# 7  2022-10-18 00:00:00+00:00  38.791280 -73.161468  44.795167    0.000388
# 8  2022-10-19 00:00:00+00:00  38.897183 -73.371453  33.398468    0.000485
# 9  2022-10-20 00:00:00+00:00  39.029084 -73.605592  24.773439    0.000539
# 10 2022-10-21 00:00:00+00:00  39.179048 -73.815980  20.148556    0.000711
# 11 2022-10-22 00:00:00+00:00  39.311116 -74.040009  14.169892    0.000763
# ...

# %%
# Create the figure
fig = plt.figure(figsize=(10.0, 10.0));

# And add panels to plot in then start adding variables
axes1 = fig.add_subplot(2, 2, 1);
ax1 = axes1.plot(daily['time'],daily['temperature'])
plt.ylabel('Temperature [°C]')
plt.grid()
plt.xticks(rotation = 30); # Rotates X-Axis Ticks by 45-degrees

axes2 = fig.add_subplot(2, 2, 2);
ax2 = axes2.plot(daily['time'],daily['salinity'])
plt.ylabel('Salinity [psu]')
plt.grid()
plt.xticks(rotation = 30); # Rotates X-Axis Ticks by 45-degrees

axes3 = fig.add_subplot(2, 2, 3);
ax3 = axes3.plot(daily['time'],daily['density'])
cb.set_label('Density [kg m-3]');
plt.grid()
plt.xticks(rotation = 30); # Rotates X-Axis Ticks by 45-degrees

axes4 = fig.add_subplot(2, 2, 4);
ax4 = axes4.plot(daily['time'],daily['sci_fl3slo_chlor_units'])
plt.ylabel('Chlorophyll-a [ug L-1]')
plt.grid()
plt.xticks(rotation = 30); # Rotates X-Axis Ticks by 45-degrees
# Out:
# <div id='9db3bac4-b790-4dc1-8645-11b18d056e6f'></div>

# %% [markdown]
# ### #3. A figure with 4-subplots of 3D (longitude, latitude, depth) plots showing temperature, salinity, density, and chlorophyll

# %% [markdown]
# ### #4. TS diagrams colored by time, one for the real-time and one for the delayed

# %% [markdown]
# ### #5. What differences do you note with the delayed dataset? Are there any advantages to using this dataset instead of the real-time? What disadvantages are there?
