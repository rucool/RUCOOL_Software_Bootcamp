# %%
# Import 
import pandas as pd
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import cmocean.cm as cmo
import datetime

# %%
# url = 'https://gliders.ioos.us/erddap/tabledap/usf-jaialai-20230806T1200.csv?trajectory%2Cwmo_id%2Cprofile_id%2Ctime%2Clatitude%2Clongitude%2Cdepth%2Cconductivity%2Cconductivity_qc%2Ccrs%2Cdensity%2Cdensity_qc%2Cdepth_qc%2Cinstrument_ctd%2Clat_uv%2Clat_uv_qc%2Clatitude_qc%2Clon_uv%2Clon_uv_qc%2Clongitude_qc%2Cplatform_meta%2Cprecise_lat%2Cprecise_lat_qc%2Cprecise_lon%2Cprecise_lon_qc%2Cprecise_time%2Cprecise_time_qc%2Cpressure%2Cpressure_qc%2Csalinity%2Csalinity_qc%2Csource_file%2Ctemperature%2Ctemperature_qc%2Ctime_qc%2Ctime_uv%2Ctime_uv_qc%2Cu%2Cu_qc%2Cv%2Cv_qc&time%3E=2023-08-24T00%3A00%3A00Z&time%3C=2023-08-31T03%3A42%3A16Z'
# df = pd.read_csv(url, sep = ',', skiprows = range(1,2), parse_dates = ['time'])
# # df.head()

# %%
df.columns
# Out:
# Index(['trajectory', 'wmo_id', 'profile_id', 'time', 'latitude', 'longitude',
#        'depth', 'conductivity', 'conductivity_qc', 'crs', 'density',
#        'density_qc', 'depth_qc', 'instrument_ctd', 'lat_uv', 'lat_uv_qc',
#        'latitude_qc', 'lon_uv', 'lon_uv_qc', 'longitude_qc', 'platform_meta',
#        'precise_lat', 'precise_lat_qc', 'precise_lon', 'precise_lon_qc',
#        'precise_time', 'precise_time_qc', 'pressure', 'pressure_qc',
#        'salinity', 'salinity_qc', 'source_file', 'temperature',
#        'temperature_qc', 'time_qc', 'time_uv', 'time_uv_qc', 'u', 'u_qc', 'v',
#        'v_qc'],
#       dtype='object')

# %%
url = 'https://gliders.ioos.us/erddap/tabledap/usf-jaialai-20230806T1200.csv?trajectory%2Cwmo_id%2Cprofile_id%2Ctime%2Clatitude%2Clongitude%2Cdepth%2Cconductivity%2Cconductivity_qc%2Ccrs%2Cdensity%2Cdensity_qc%2Cdepth_qc%2Cinstrument_ctd%2Clat_uv%2Clat_uv_qc%2Clatitude_qc%2Clon_uv%2Clon_uv_qc%2Clongitude_qc%2Cplatform_meta%2Cprecise_lat%2Cprecise_lat_qc%2Cprecise_lon%2Cprecise_lon_qc%2Cprecise_time%2Cprecise_time_qc%2Cpressure%2Cpressure_qc%2Csalinity%2Csalinity_qc%2Csource_file%2Ctemperature%2Ctemperature_qc%2Ctime_qc%2Ctime_uv%2Ctime_uv_qc%2Cu%2Cu_qc%2Cv%2Cv_qc&time%3E=2023-08-24T00%3A00%3A00Z&time%3C=2023-08-31T03%3A42%3A16Z'
df = pd.read_csv(url, sep = ',', skiprows = range(1,2), parse_dates = ['time'])
# df.head()

fig = plt.figure(figsize=(10,4))
plt.scatter(df['time'],-df['depth'],20,df['temperature'],vmin = 20, vmax = 32, cmap = cmo.thermal)
plt.colorbar()
plt.ylim(-100,0)
plt.xlim(datetime.date(2023,8,26),)
# Out:
# (19595.0, 19600.43984085648)

# %%
# url = 'https://gliders.ioos.us/erddap/tabledap/usf-jaialai-20230806T1200.csv?trajectory%2Cwmo_id%2Cprofile_id%2Ctime%2Clatitude%2Clongitude%2Cdepth%2Cconductivity%2Cconductivity_qc%2Ccrs%2Cdensity%2Cdensity_qc%2Cdepth_qc%2Cinstrument_ctd%2Clat_uv%2Clat_uv_qc%2Clatitude_qc%2Clon_uv%2Clon_uv_qc%2Clongitude_qc%2Cplatform_meta%2Cprecise_lat%2Cprecise_lat_qc%2Cprecise_lon%2Cprecise_lon_qc%2Cprecise_time%2Cprecise_time_qc%2Cpressure%2Cpressure_qc%2Csalinity%2Csalinity_qc%2Csource_file%2Ctemperature%2Ctemperature_qc%2Ctime_qc%2Ctime_uv%2Ctime_uv_qc%2Cu%2Cu_qc%2Cv%2Cv_qc&time%3E=2023-08-24T00%3A00%3A00Z&time%3C=2023-08-31T03%3A42%3A16Z'
url = 
df = pd.read_csv(url, sep = ',', skiprows = range(1,2), parse_dates = ['time'])
# df.head()

fig = plt.figure(figsize=(10,4))
plt.scatter(df['time'],-df['depth'],20,df['temperature'],vmin = 20, vmax = 32, cmap = cmo.thermal)
plt.colorbar()
plt.ylim(-100,0)
plt.xlim(datetime.date(2023,8,26),)
# Out:
#   Cell In[28], line 2
#     url =
#           ^
# SyntaxError: invalid syntax
