# %% [markdown]
# # Exercise 04 - Indexing and max
#
# ### Tasks
#
# 1. select the data for the first patient and save it as a new variable `patient_0` (hints: use indexing. also you can use the `:` symbol to mean 'give me all the data' in a particular dimention. indexing this matrix goes `data[rows, columns]`
# 1. calculate the maximum inflamation for `patient_0` using `numpy.max()`, another method/function from numpy. print out the max inflammation

# %%
import numpy
data = numpy.loadtxt('../data/inflammation-01.csv', delimiter=',')
